# %%
from baselines.common import plot_util as pu
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Logging to /tmp/openai-2018-11-22-08-29-11-574392

# %% [markdown]
# # Space Invaders PPO2 R1 vs R2

# %%
results = pu.load_results('logs/si_10M_ppo2')
r = results[0]
#plt.plot(np.cumsum(r.monitor.l), r.monitor.r)
plt.plot(np.cumsum(r.monitor.l), pu.smooth(r.monitor.r, radius=10))


results = pu.load_results('logs/si_10M_ppo2_2')
r2 = results[0]
#plt.plot(np.cumsum(r.monitor.l), r.monitor.r)
plt.plot(np.cumsum(r2.monitor.l), pu.smooth(r2.monitor.r, radius=10))

# %% [markdown]
# # Space Invaders ACKTR R1 v R2

# %%
results = pu.load_results('logs/si_10M_acktr')
r = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r.monitor.l), pu.smooth(r.monitor.r, radius=10))

results = pu.load_results('logs/si_10M_acktr_2')
r2 = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r2.monitor.l), pu.smooth(r2.monitor.r, radius=10))

# %% [markdown]
# # Pong PPO2 R1 v R2

# %%
results = pu.load_results('logs/pong_10M_ppo2')
r = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r.monitor.l), pu.smooth(r.monitor.r, radius=10))

results = pu.load_results('logs/pong_10M_ppo2_2')
r2 = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r2.monitor.l), pu.smooth(r2.monitor.r, radius=10))

# %% [markdown]
# # SI-Pong PPO2 R1 v R2

# %%
results = pu.load_results('logs/si-pong_10M_ppo2')
r = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r.monitor.l), pu.smooth(r.monitor.r, radius=10))

results = pu.load_results('logs/si-pong_10M_ppo2_2')
r2 = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r2.monitor.l), pu.smooth(r2.monitor.r, radius=10))

# %% [markdown]
# # Pong ACKTR R1 v R2

# %%
results = pu.load_results('logs/pong_10M_acktr_1')
r = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r.monitor.l), pu.smooth(r.monitor.r, radius=10))

results = pu.load_results('logs/pong_10M_acktr_2')
r2 = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r2.monitor.l), pu.smooth(r2.monitor.r, radius=10))

# %% [markdown]
# # SI-Pong ACKTR R1 v R2

# %%
results = pu.load_results('logs/si-pong_10M_acktr')
r = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r.monitor.l), pu.smooth(r.monitor.r, radius=10))

results = pu.load_results('logs/si-pong_10M_acktr_2')
r2 = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r2.monitor.l), pu.smooth(r2.monitor.r, radius=10))

# %% [markdown]
# # Demon Attack ACKTR R1 v R2

# %%
results = pu.load_results('logs/da_10M_acktr_1')
r = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r.monitor.l), pu.smooth(r.monitor.r, radius=10))

results = pu.load_results('logs/da_10M_acktr_2')
r2 = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r2.monitor.l), pu.smooth(r2.monitor.r, radius=10))

# %% [markdown]
# # SI-DA ACKTR R1 v R2

# %%
results = pu.load_results('logs/si_da_10M_acktr')
r = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r.monitor.l), pu.smooth(r.monitor.r, radius=10))

results = pu.load_results('logs/si_da_10M_acktr_2')
r2 = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r2.monitor.l), pu.smooth(r2.monitor.r, radius=10))

# %% [markdown]
# # Demon Attack PPO2 R1 v R2

# %%
results = pu.load_results('logs/da_10M_ppo2')
r = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r.monitor.l), pu.smooth(r.monitor.r, radius=10))

results = pu.load_results('logs/da_10M_ppo2_2')
r2 = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r2.monitor.l), pu.smooth(r2.monitor.r, radius=10))

# %% [markdown]
# # QBert PPO2 R1 v R2

# %%
results = pu.load_results('logs/qb_10M_acktr')
r = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r.monitor.l), pu.smooth(r.monitor.r, radius=10))

results = pu.load_results('logs/qb_10M_ppo2')
r2 = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r2.monitor.l), pu.smooth(r2.monitor.r, radius=10))
