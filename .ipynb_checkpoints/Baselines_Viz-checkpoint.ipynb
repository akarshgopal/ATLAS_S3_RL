# %%
from baselines.common import plot_util as pu
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Logging to /tmp/openai-2018-11-26-14-10-39-129382

# %% [markdown]
# # Space Invaders PPO2 R1 vs R2

# %%
results = pu.load_results('logs/si_10M_ppo2_1')
r = results[0]
#plt.plot(np.cumsum(r.monitor.l), r.monitor.r)
plt.plot(np.cumsum(r.monitor.l), pu.smooth(r.monitor.r, radius=100))


results = pu.load_results('logs/si_10M_ppo2_2')
r2 = results[0]
#plt.plot(np.cumsum(r.monitor.l), r.monitor.r)
plt.plot(np.cumsum(r2.monitor.l), pu.smooth(r2.monitor.r, radius=100))
# Out:
# /home/agopal/Projects/Baselines/baselines/baselines/bench/monitor.py:164: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.headers = headers # HACK to preserve backwards compatibility

# %% [markdown]
# # QB-SI PPO2

# %%
results = pu.load_results('logs/qb_si_10M_ppo2_1')
r = results[0]
#plt.plot(np.cumsum(r.monitor.l), r.monitor.r)
plt.plot(np.cumsum(r.monitor.l), pu.smooth(r.monitor.r, radius=100))


results = pu.load_results('logs/qb_si_10M_ppo2_2')
r2 = results[0]
#plt.plot(np.cumsum(r.monitor.l), r.monitor.r)
plt.plot(np.cumsum(r2.monitor.l), pu.smooth(r2.monitor.r, radius=100))

# %% [markdown]
# # Space Invaders ACKTR R1 v R2

# %%
results = pu.load_results('logs/si_10M_acktr_1')
r = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r.monitor.l), pu.smooth(r.monitor.r, radius=100))

results = pu.load_results('logs/si_10M_acktr_2')
r2 = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r2.monitor.l), pu.smooth(r2.monitor.r, radius=100))

# %% [markdown]
# # QB-Si Acktr

# %%
results = pu.load_results('logs/qb_si_10M_acktr_1')
r = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r.monitor.l), pu.smooth(r.monitor.r, radius=100))

results = pu.load_results('logs/qb_si_10M_acktr_2')
r2 = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r2.monitor.l), pu.smooth(r2.monitor.r, radius=100))

# %% [markdown]
# # Pong PPO2 R1 v R2

# %%
results = pu.load_results('logs/pong_10M_ppo2_1')
r = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r.monitor.l), pu.smooth(r.monitor.r, radius=100))

results = pu.load_results('logs/pong_10M_ppo2_2')
r2 = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r2.monitor.l), pu.smooth(r2.monitor.r, radius=100))

# %% [markdown]
# # SI-Pong PPO2 R1 v R2

# %%
results = pu.load_results('logs/si_pong_10M_ppo2_1')
r = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r.monitor.l), pu.smooth(r.monitor.r, radius=100))

results = pu.load_results('logs/si_pong_10M_ppo2_2')
r2 = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r2.monitor.l), pu.smooth(r2.monitor.r, radius=100))

# %% [markdown]
# # QBert Pong PPO2

# %%
results = pu.load_results('logs/qb_pong_10M_ppo2_1')
r = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r.monitor.l), pu.smooth(r.monitor.r, radius=100))

results = pu.load_results('logs/qb_pong_10M_ppo2_2')
r2 = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r2.monitor.l), pu.smooth(r2.monitor.r, radius=100))

# %% [markdown]
# # Pong ACKTR R1 v R2

# %%
results = pu.load_results('logs/pong_10M_acktr_1')
r = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r.monitor.l), pu.smooth(r.monitor.r, radius=100))

results = pu.load_results('logs/pong_10M_acktr_2')
r2 = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r2.monitor.l), pu.smooth(r2.monitor.r, radius=100))

# %% [markdown]
# # SI-Pong ACKTR R1 v R2

# %%
results = pu.load_results('logs/si_pong_10M_acktr_1')
r = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r.monitor.l), pu.smooth(r.monitor.r, radius=100))

results = pu.load_results('logs/si_pong_10M_acktr_2')
r2 = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r2.monitor.l), pu.smooth(r2.monitor.r, radius=100))

# %% [markdown]
# # Demon Attack ACKTR R1 v R2

# %%
results = pu.load_results('logs/da_10M_acktr_1')
r = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r.monitor.l), pu.smooth(r.monitor.r, radius=100))

results = pu.load_results('logs/da_10M_acktr_2')
r2 = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r2.monitor.l), pu.smooth(r2.monitor.r, radius=100))

# %% [markdown]
# # SI-DA ACKTR R1 v R2

# %%
results = pu.load_results('logs/si_da_10M_acktr_1')
r = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r.monitor.l), pu.smooth(r.monitor.r, radius=100))

results = pu.load_results('logs/si_da_10M_acktr_2')
r2 = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r2.monitor.l), pu.smooth(r2.monitor.r, radius=100))

# %% [markdown]
# # Demon Attack PPO2 R1 v R2

# %%
results = pu.load_results('logs/da_10M_ppo2_1')
r = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r.monitor.l), pu.smooth(r.monitor.r, radius=100))

results = pu.load_results('logs/da_10M_ppo2_2')
r2 = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r2.monitor.l), pu.smooth(r2.monitor.r, radius=100))

# %% [markdown]
# # SI-DA PPO2

# %%
results = pu.load_results('logs/si_da_10M_ppo2_1')
r = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r.monitor.l), pu.smooth(r.monitor.r, radius=100))

results = pu.load_results('logs/si_da_10M_ppo2_2')
r2 = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r2.monitor.l), pu.smooth(r2.monitor.r, radius=100))

# %% [markdown]
# # QBert PPO2 R1 v R2

# %%
results = pu.load_results('logs/qb_10M_ppo2_1')
r = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r.monitor.l), pu.smooth(r.monitor.r, radius=100))

results = pu.load_results('logs/qb_10M_ppo2_2')
r2 = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r2.monitor.l), pu.smooth(r2.monitor.r, radius=100))

# %% [markdown]
# # SI-QB PPO2

# %%
results = pu.load_results('logs/si_qb_10M_ppo2_1')
r = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r.monitor.l), pu.smooth(r.monitor.r, radius=100))

results = pu.load_results('logs/si_qb_10M_ppo2_2')
r2 = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r2.monitor.l), pu.smooth(r2.monitor.r, radius=100))

# %% [markdown]
# # QBert ACKTR R1 v R2

# %%
results = pu.load_results('logs/qb_10M_acktr_1')
r = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r.monitor.l), pu.smooth(r.monitor.r, radius=100))

results = pu.load_results('logs/qb_10M_acktr_2')
r2 = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r2.monitor.l), pu.smooth(r2.monitor.r, radius=100))

# %% [markdown]
# # Si-qb ACKTR

# %%
results = pu.load_results('logs/si_qb_10M_acktr_1')
r = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r.monitor.l), pu.smooth(r.monitor.r, radius=100))

results = pu.load_results('logs/si_qb_10M_acktr_2')
r2 = results[0]
#plt.plot(np.cumsum(r2.monitor.l), r2.monitor.r)
plt.plot(np.cumsum(r2.monitor.l), pu.smooth(r2.monitor.r, radius=100))
